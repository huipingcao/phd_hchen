# %% [markdown]
# # Design Choices
# In this notebook, we determine the best ClaSP parameters.

# %%
import numpy as np
import pandas as pd
import daproli as dp

import pandas as pd
pd.set_option('display.max_rows', None)

import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme()
sns.set_color_codes()

import Orange
import sys
sys.path.append("../")

from tqdm import tqdm
from itertools import product

# %% [markdown]
# Let's load the scores from the different methods.

# %%
neighbours = (1, 3, 5)
scores = ("_f1_score", "roc_auc_score")

scores_lookup = {
    "_f1_score" : "F1",
    "roc_auc_score" : "ROC-AUC"
}

methods = [
    (f"{n_neighbours}-NN {scores_lookup[score]}", f"{n_neighbours}-{score}.csv")
    for n_neighbours, score in product(neighbours, scores)
]

for idx, (name, file_name) in enumerate(methods):
    methods[idx] = name, pd.read_csv(f"../experiments/parameter/{file_name}")
    
df_scores = pd.DataFrame()

for name, df in methods:
    df_scores["name"] = df.name
    df_scores[name] = df.score

# %%
df_scores
# Out:
#                                                 name   1-NN F1  1-NN ROC-AUC  \
# 0                                               Cane  0.050000      0.015356
# 1                                       DutchFactory  0.002055      0.002055
# 2                                             EEGRat  0.002000      0.001500
# 3                                            EEGRat2  0.136000      0.136000
# 4                                          Fetal2013  0.000500      0.001889
# 5                                   GrandMalSeizures  0.000977      0.000977
# 6                                  GrandMalSeizures2  0.002492      0.002492
# 7                                       GreatBarbet1  0.004468      0.009149
# 8                                       GreatBarbet2  0.005745      0.008723
# 9                                         InsectEPG1  0.011705      0.011705
# 10                                        InsectEPG2  0.009499      0.007999
# 11                                        InsectEPG3  0.007142      0.007142
# 12                                        InsectEPG4  0.039419      0.039261
# 13                                          NogunGun  0.004876      0.004876
# 14          PigInternalBleedingDatasetAirwayPressure  0.057570      0.057570
# 15  PigInternalBleedingDatasetArtPressureFluidFilled  0.000200      0.003940
# 16                     PigInternalBleedingDatasetCVP  0.006478      0.004742
# 17                                       Powerdemand  0.000911      0.000911
# 18                               PulsusParadoxusECG1  0.000913      0.000000
# 19                               PulsusParadoxusECG2  0.000171      0.000171
# 20                               PulsusParadoxusSP02  0.001199      0.001199
# 21                               RoboticDogActivityX  0.002441      0.002441
# 22                               RoboticDogActivityY  0.002109      0.002109
# 23                               RoboticDogActivityZ  0.000364      0.000273
# 24                                   SimpleSynthetic  0.015248      0.017873
# 25                               SuddenCardiacDeath1  0.027500      0.010583
# 26                               SuddenCardiacDeath2  0.000333      0.000333
# 27                               SuddenCardiacDeath3  0.001667      0.001667
# 28                                           TiltABP  0.002325      0.002325
# 29                                           TiltECG  0.009750      0.009750
# 30                                       WalkJogRun1  0.041596      0.041796
# 31                                       WalkJogRun2  0.030397      0.016098
# 32                                             Adiac  0.014205      0.012074
# 33                                         ArrowHead  0.002656      0.001992
# 34                                              Beef  0.030496      0.032624
# 35                                         BeetleFly  0.016406      0.016406
# 36                                       BirdChicken  0.400000      0.299609
# 37                                               Car  0.030051      0.031438
# 38                                               CBF  0.028125      0.030208
# 39                             ChlorineConcentration  0.000128      0.000000
# 40                                      CinCECGTorso  0.013949      0.013949
# 41                                            Coffee  0.003000      0.005000
# 42                                         Computers  0.085244      0.085244
# 43                                          CricketX  0.003234      0.003234
# 44                                          CricketY  0.008458      0.008458
# 45                                          CricketZ  0.040118      0.023555
# 46                               DiatomSizeReduction  0.139211      0.134571
# 47                      DistalPhalanxOutlineAgeGroup  0.022378      0.022378
# 48                                   DistalPhalanxTW  0.033721      0.004264
# 49                                       Earthquakes  0.072011      0.072011
# 50                                            ECG200  0.015833      0.015833
# 51                                           ECG5000  0.000000      0.000000
# 52                                       ECGFiveDays  0.014066      0.014066
# 53                                   ElectricDevices  0.016996      0.128772
# 54                                           FaceAll  0.005453      0.005453
# 55                                          FaceFour  0.017619      0.017619
# 56                                          FacesUCR  0.006941      0.014037
# 57                                        FiftyWords  0.005196      0.005196
# 58                                              Fish  0.012149      0.012149
# 59                                          GunPoint  0.004800      0.004800
# 60                                           Haptics  0.113497      0.113497
# 61                                       InlineSkate  0.097698      0.097698
# 62                               InsectWingbeatSound  0.010938      0.008594
# 63                                  ItalyPowerDemand  0.011816      0.002488
# 64                            LargeKitchenAppliances  0.012565      0.012565
# 65                                        Lightning2  0.191792      0.191792
# 66                                        Lightning7  0.147423      0.148188
# 67                                            Mallat  0.008317      0.008317
# 68                                              Meat  0.004464      0.004167
# 69                                     MedicalImages  0.003638      0.003638
# 70                                        MoteStrain  0.040476      0.040476
# 71                        NonInvasiveFetalECGThorax1  0.003543      0.003301
# 72                        NonInvasiveFetalECGThorax2  0.002268      0.002127
# 73                                          OliveOil  0.009717      0.009717
# 74                                           OSULeaf  0.001923      0.001923
# 75                                             Plane  0.004233      0.005291
# 76                    ProximalPhalanxOutlineAgeGroup  0.062750      0.062750
# 77                                 ProximalPhalanxTW  0.010250      0.010000
# 78                                         ShapesAll  0.012344      0.012344
# 79                             SonyAIBORobotSurface1  0.004286      0.004286
# 80                             SonyAIBORobotSurface2  0.006838      0.006838
# 81                                   StarLightCurves  0.001563      0.001563
# 82                                       SwedishLeaf  0.005744      0.005744
# 83                                           Symbols  0.063526      1.000000
# 84                                  SyntheticControl  0.004267      0.003467
# 85                                  ToeSegmentation1  0.002888      0.000000
# 86                                  ToeSegmentation2  0.004861      0.004861
# 87                                             Trace  0.024577      0.024577
# 88                                        TwoLeadECG  0.343949      0.346072
# 89                                       TwoPatterns  0.002375      0.002375
# 90                            UWaveGestureLibraryAll  0.002483      0.002483
# 91                              UWaveGestureLibraryX  0.012420      0.012065
# 92                              UWaveGestureLibraryY  0.021647      0.022001
# 93                              UWaveGestureLibraryZ  0.143364      0.143364
# 94                                             Wafer  0.004212      0.004212
# 95                                      WordSynonyms  0.002088      0.002088
# 96                                             Worms  0.012136      0.012136
# 97                                              Yoga  0.004445      0.004445
#
#      3-NN F1  3-NN ROC-AUC   5-NN F1  5-NN ROC-AUC
# 0   0.050000      0.001124  0.005431      0.005805
# 1   0.002055      0.002055  0.002055      0.002055
# 2   0.004500      0.001500  0.003500      0.001500
# 66  0.082276      0.065912  0.005658      1.000000
# 67  0.019657      0.002016  0.018397      0.019657
# 68  0.001190      0.001190  0.001190      0.004464
# 69  0.004446      0.004446  0.002425      0.002425
# 70  0.001786      0.001786  0.010119      0.008929
# 71  0.003945      0.002818  0.005314      0.002899
# 72  0.002765      0.002197  0.003403      0.004537
# 73  0.004318      0.004453  0.004049      0.004318
# 74  0.003846      0.002404  0.006250      0.006250
# 75  0.004497      0.004233  0.002910      0.004233
# 76  0.062500      0.062500  0.064750      0.062750
# 77  0.011000      0.009250  0.010500      0.008500
# 78  0.012031      0.011406  0.013281      0.014062
# 79  0.001429      0.001429  0.006429      0.007857
# 80  0.006838      0.006838  0.089459      0.007407
# 81  0.004689      0.004689  0.001250      0.000938
# 82  0.006664      0.005055  0.002068      0.002068
# 83  0.012705      0.012705  0.008999      0.372684
# 84  0.005333      0.005067  0.005600      0.005600
# 85  0.000000      0.000000  0.002888      0.002888
# 86  0.004861      0.004861  0.005185      0.005185
# 87  0.017499      0.009831  0.017499      0.010028
# 88  0.002123      0.002123  0.012739      0.012739
# 89  0.005125      0.005500  0.003000      0.003000
# 90  0.003901      0.003901  0.004019      0.003901
# 91  0.004613      0.006742  0.004968      0.005678
# 92  0.018453      0.019163  0.014194      0.014549
# 93  0.048261      0.074166  0.023066      0.099006
# 94  0.004212      0.004212  0.008425      0.008425
# 95  0.007516      0.002505  0.005846      0.002088
# 96  0.009709      0.015372  0.215210      0.298544
# 97  0.002692      0.002692  0.002692      0.002692

# %% [markdown]
# Let's calculate the mean/std error.

# %%
for name in df_scores.columns[1:]:
    print(f"{name}: mean_error={np.round(df_scores[name].mean(), 5)}")
# Out:
# 1-NN F1: mean_error=0.02998
# 1-NN ROC-AUC: mean_error=0.03856
# 3-NN F1: mean_error=0.0139
# 3-NN ROC-AUC: mean_error=0.01293
# 5-NN F1: mean_error=0.02143
# 5-NN ROC-AUC: mean_error=0.03719

# %%
for name in df_scores.columns[1:]:
    print(f"{name}: std_error={np.round(df_scores[name].std(), 5)}")
# Out:
# 1-NN F1: std_error=0.06207
# 1-NN ROC-AUC: std_error=0.11366
# 3-NN F1: std_error=0.02149
# 3-NN ROC-AUC: std_error=0.02465
# 5-NN F1: std_error=0.05005
# 5-NN ROC-AUC: std_error=0.11615

# %% [markdown]
# Let's determine and plot the ranks.

# %%
ranks = df_scores.rank(1, method = 'min', ascending=True)
means = np.array(ranks.mean(axis=0))

# %%
for name in df_scores.columns[1:]:
    print(f"{name}: wins={ranks[ranks[name] == 1].shape[0]}")
# Out:
# 1-NN F1: wins=20
# 1-NN ROC-AUC: wins=30
# 3-NN F1: wins=37
# 3-NN ROC-AUC: wins=39
# 5-NN F1: wins=28
# 5-NN ROC-AUC: wins=28

# %%
cd = Orange.evaluation.scoring.compute_CD(means, df_scores.shape[0])
Orange.evaluation.scoring.graph_ranks(means, df_scores.columns[1:], cd=cd, width=8, reverse=True, textspace=2.5)
